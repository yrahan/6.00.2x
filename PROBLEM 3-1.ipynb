# %%
# %load_ext autoreload%autoreload 2

# %%
# !ls
# Out:
# cityTemps.txt	   PROBLEM 1 - LINKAGE CRITERIA.ipynb	 ProblemSet6.zipclusterCities.py   PROBLEM 2 - MERGING CLUSTERS  .ipynb  test.txtclusterCities.pyc  PROBLEM 3-1.ipynb

# %%
# !head cityTemps.txt
# Out:
# #city#Jan. temp (F)#April temp (F)#July temp (F)#Oct. temp (F)#annual precipitation (inches)#annual precipitation (days)#endAlbany,22.2,46.6,71.1,49.3,38.60,136Albuquerque,35.7,55.6,78.5,57.3,9.47,60

# %%
from clusterCities import *# test()

# %%
points = buildCityPoints('cityTemps.txt', False)hCluster(points, Cluster.singleLinkageDist, 10, False)
# Out:
# Final set of clusters:  C0:Albany, Asheville, Atlanta, AtlantiCity, Austin, Baltimore, BatonRouge, Billings, Birmingham, Bismarck, Boise, Boston, Bridgeport, Buffalo, Burlington, Caribou, Casper, Charleston, Charleston, Charlotte, Cheyenne, Chicago, Cleveland, Columbia, Columbus, Concord, Dallas, Denver, DesMoines, Detroit, DodgeCity, Fargo, GrandJunction, GrandRapids, Hartford, Helena, Houston, Indianapolis, Jackson, Jacksonville, KansasCity, Knoxville, Lexington, LittleRock, Louisville, Madison, Memphis, Milwaukee, Minneapolis, Mobile, Montgomery, Nashville, NewOrleans, NewYork, Newark, Norfolk, OklahomaCity, Omaha, Philadelphia, Pittsburgh, PortlandME, PortlandOR, Providence, Raleigh, Richmond, SaltLakeCity, SanAntonio, Savannah, Seattle, SiouxFalls, Spokane, Springfield, StLouis, Tampa, Toledo, Tulsa, Washington, Wichita, Wilmington  C1:Albuquerque, ElPaso, Reno, Roswell, Sacramento, SanFrancisco, Tucson  C2:Anchorage  C3:Duluth  C4:Fairbanks  C5:Honolulu  C6:LasVegas, Phoenix  C
# ...

# %%
points = buildCityPoints('cityTemps.txt', False)hCluster(points, Cluster.maxLinkageDist, 10, False)
# Out:
# Final set of clusters:  C0:Albany, Asheville, AtlantiCity, Baltimore, Boston, Bridgeport, Charlotte, Chicago, Columbus, Concord, DesMoines, Detroit, Hartford, Indianapolis, KansasCity, Knoxville, Lexington, Louisville, Milwaukee, NewYork, Newark, Philadelphia, PortlandME, Providence, Raleigh, Richmond, Springfield, StLouis, Toledo, Washington, Wilmington  C1:Albuquerque, DodgeCity, GrandJunction, Reno, Sacramento, SanFrancisco  C2:Anchorage, Billings, Bismarck, Boise, Casper, Cheyenne, Denver, Fargo, Helena, Madison, Minneapolis, Omaha, SaltLakeCity, SiouxFalls, Spokane  C3:Atlanta, BatonRouge, Birmingham, Charleston, Columbia, Houston, Jackson, Jacksonville, LittleRock, Memphis, Miami, Mobile, Montgomery, Nashville, NewOrleans, Norfolk, Savannah, Tampa, VeroBeach  C4:Austin, Dallas, OklahomaCity, SanAntonio, Tulsa, Wichita  C5:Buffalo, Charleston, Cleveland, Olympia, Pittsburgh, PortlandOR, Seattle  C6:Burlington, Caribou, Duluth, GrandRapids  C7:ElPaso, LasVegas, LongBeach, LosAnge
# ...

# %%
points = buildCityPoints('cityTemps.txt', False)hCluster(points, Cluster.averageLinkageDist, 10, False)
# Out:
# Final set of clusters:  C0:Albany, Asheville, AtlantiCity, Baltimore, Boston, Bridgeport, Charlotte, Chicago, Columbus, Concord, DesMoines, Detroit, Duluth, GrandRapids, Hartford, Indianapolis, KansasCity, Knoxville, Lexington, Louisville, Madison, Milwaukee, Minneapolis, Nashville, NewYork, Newark, Norfolk, Omaha, Philadelphia, PortlandME, Providence, Raleigh, Richmond, Springfield, StLouis, Toledo, Washington, Wilmington  C1:Albuquerque, ElPaso, Reno, Roswell, Sacramento, SanFrancisco, Tucson  C2:Anchorage  C3:Atlanta, BatonRouge, Birmingham, Charleston, Columbia, Houston, Jackson, Jacksonville, LittleRock, Memphis, Miami, Mobile, Montgomery, NewOrleans, Savannah, Tampa, VeroBeach  C4:Austin, Dallas, OklahomaCity, SanAntonio, Tulsa, Wichita  C5:Billings, Bismarck, Boise, Casper, Cheyenne, Denver, DodgeCity, Fargo, GrandJunction, Helena, SaltLakeCity, SiouxFalls, Spokane  C6:Buffalo, Burlington, Caribou, Charleston, Cleveland, Olympia, Pittsburgh, PortlandOR, Seattle  C7:Fairbanks  
# ...

# %%
points = buildCityPoints('cityTemps.txt', True)hCluster(points, Cluster.singleLinkageDist, 10, True)
# Out:
# Step 0 Merged ['Detroit'] with ['Toledo']Step 1 Merged ['Austin'] with ['SanAntonio']Step 2 Merged ['Baltimore'] with ['Wilmington']Step 3 Merged ['Jackson'] with ['Montgomery']Step 4 Merged ['Philadelphia'] with ['Baltimore', 'Wilmington']Step 5 Merged ['Charleston'] with ['Savannah']Step 6 Merged ['Atlanta'] with ['Birmingham']Step 7 Merged ['Newark'] with ['NewYork']Step 8 Merged ['LittleRock'] with ['Memphis']Step 9 Merged ['Hartford'] with ['Providence']Step 10 Merged ['Albany'] with ['GrandRapids']Step 11 Merged ['Boston'] with ['Bridgeport']Step 12 Merged ['Philadelphia', 'Baltimore', 'Wilmington'] with ['Newark', 'NewYork']Step 13 Merged ['Norfolk'] with ['Raleigh']Step 14 Merged ['Jackson', 'Montgomery'] with ['Charleston', 'Savannah']Step 15 Merged ['Hartford', 'Providence'] with ['Boston', 'Bridgeport']Step 16 Merged ['Cleveland'] with ['Pittsburgh']Step 17 Merged ['Nashville'] with ['Norfolk', 'Raleigh']Step 18 Merged ['AtlantiCity'] with ['Philadelphia', 'Baltimore', 'Wi
# ...

# %%
points = buildCityPoints('cityTemps.txt', True)hCluster(points, Cluster.averageLinkageDist, 10, True)
# Out:
# Step 0 Merged ['Detroit'] with ['Toledo']Step 1 Merged ['Austin'] with ['SanAntonio']Step 2 Merged ['Baltimore'] with ['Wilmington']Step 3 Merged ['Jackson'] with ['Montgomery']Step 4 Merged ['Charleston'] with ['Savannah']Step 5 Merged ['Philadelphia'] with ['Baltimore', 'Wilmington']Step 6 Merged ['Atlanta'] with ['Birmingham']Step 7 Merged ['Newark'] with ['NewYork']Step 8 Merged ['LittleRock'] with ['Memphis']Step 9 Merged ['Hartford'] with ['Providence']Step 10 Merged ['Albany'] with ['GrandRapids']Step 11 Merged ['Boston'] with ['Bridgeport']Step 12 Merged ['Norfolk'] with ['Raleigh']Step 13 Merged ['Cleveland'] with ['Pittsburgh']Step 14 Merged ['Knoxville'] with ['Nashville']Step 15 Merged ['Chicago'] with ['Milwaukee']Step 16 Merged ['BatonRouge'] with ['NewOrleans']Step 17 Merged ['Hartford', 'Providence'] with ['Boston', 'Bridgeport']Step 18 Merged ['Richmond'] with ['Washington']Step 19 Merged ['Bismarck'] with ['Fargo']Step 20 Merged ['AtlantiCity'] with ['Philadelphia',
# ...

# %%
points = buildCityPoints('cityTemps.txt', True)hCluster(points, Cluster.maxLinkageDist, 10, True)
# Out:
# Step 0 Merged ['Detroit'] with ['Toledo']Step 1 Merged ['Austin'] with ['SanAntonio']Step 2 Merged ['Baltimore'] with ['Wilmington']Step 3 Merged ['Jackson'] with ['Montgomery']Step 4 Merged ['Charleston'] with ['Savannah']Step 5 Merged ['Atlanta'] with ['Birmingham']Step 6 Merged ['Newark'] with ['NewYork']Step 7 Merged ['Philadelphia'] with ['Baltimore', 'Wilmington']Step 8 Merged ['LittleRock'] with ['Memphis']Step 9 Merged ['Hartford'] with ['Providence']Step 10 Merged ['Albany'] with ['GrandRapids']Step 11 Merged ['Boston'] with ['Bridgeport']Step 12 Merged ['Norfolk'] with ['Raleigh']Step 13 Merged ['Cleveland'] with ['Pittsburgh']Step 14 Merged ['Knoxville'] with ['Nashville']Step 15 Merged ['Chicago'] with ['Milwaukee']Step 16 Merged ['BatonRouge'] with ['NewOrleans']Step 17 Merged ['Richmond'] with ['Washington']Step 18 Merged ['Bismarck'] with ['Fargo']Step 19 Merged ['Columbus'] with ['Indianapolis']Step 20 Merged ['LosAngeles'] with ['SanDiego']Step 21 Merged ['Casper'] w
# ...

# %%
points = buildCityPoints('cityTemps.txt', True)hCluster(points, Cluster.averageLinkageDist, 5, True)
# Out:
# Step 0 Merged ['Detroit'] with ['Toledo']Step 1 Merged ['Austin'] with ['SanAntonio']Step 2 Merged ['Baltimore'] with ['Wilmington']Step 3 Merged ['Jackson'] with ['Montgomery']Step 4 Merged ['Charleston'] with ['Savannah']Step 5 Merged ['Philadelphia'] with ['Baltimore', 'Wilmington']Step 6 Merged ['Atlanta'] with ['Birmingham']Step 7 Merged ['Newark'] with ['NewYork']Step 8 Merged ['LittleRock'] with ['Memphis']Step 9 Merged ['Hartford'] with ['Providence']Step 10 Merged ['Albany'] with ['GrandRapids']Step 11 Merged ['Boston'] with ['Bridgeport']Step 12 Merged ['Norfolk'] with ['Raleigh']Step 13 Merged ['Cleveland'] with ['Pittsburgh']Step 14 Merged ['Knoxville'] with ['Nashville']Step 15 Merged ['Chicago'] with ['Milwaukee']Step 16 Merged ['BatonRouge'] with ['NewOrleans']Step 17 Merged ['Hartford', 'Providence'] with ['Boston', 'Bridgeport']Step 18 Merged ['Richmond'] with ['Washington']Step 19 Merged ['Bismarck'] with ['Fargo']Step 20 Merged ['AtlantiCity'] with ['Philadelphia',
# ...

# %%
points = buildCityPoints('cityTemps.txt', False)hCluster(points, Cluster.averageLinkageDist, 5, False)
# Out:
# Final set of clusters:  C0:Albany, Asheville, Atlanta, AtlantiCity, Baltimore, BatonRouge, Birmingham, Boston, Bridgeport, Buffalo, Burlington, Caribou, Charleston, Charleston, Charlotte, Chicago, Cleveland, Columbia, Columbus, Concord, DesMoines, Detroit, Duluth, GrandRapids, Hartford, Houston, Indianapolis, Jackson, Jacksonville, KansasCity, Knoxville, Lexington, LittleRock, Louisville, Madison, Memphis, Miami, Milwaukee, Minneapolis, Mobile, Montgomery, Nashville, NewOrleans, NewYork, Newark, Norfolk, Olympia, Omaha, Philadelphia, Pittsburgh, PortlandME, PortlandOR, Providence, Raleigh, Richmond, Savannah, Seattle, Springfield, StLouis, Tampa, Toledo, VeroBeach, Washington, Wilmington  C1:Albuquerque, ElPaso, LasVegas, LongBeach, LosAngeles, Phoenix, Reno, Roswell, Sacramento, SanDiego, SanFrancisco, Tucson  C2:Anchorage, Fairbanks  C3:Austin, Billings, Bismarck, Boise, Casper, Cheyenne, Dallas, Denver, DodgeCity, Fargo, GrandJunction, Helena, OklahomaCity, SaltLakeCity, SanAntoni
# ...

# %%
points = buildCityPoints('cityTemps.txt', False)hCluster(points, Cluster.singleLinkageDist, 5, False)
# Out:
# Final set of clusters:  C0:Albany, Albuquerque, Asheville, Atlanta, AtlantiCity, Austin, Baltimore, BatonRouge, Billings, Birmingham, Bismarck, Boise, Boston, Bridgeport, Buffalo, Burlington, Caribou, Casper, Charleston, Charleston, Charlotte, Cheyenne, Chicago, Cleveland, Columbia, Columbus, Concord, Dallas, Denver, DesMoines, Detroit, DodgeCity, Duluth, ElPaso, Fargo, GrandJunction, GrandRapids, Hartford, Helena, Houston, Indianapolis, Jackson, Jacksonville, KansasCity, Knoxville, LasVegas, Lexington, LittleRock, Louisville, Madison, Memphis, Miami, Milwaukee, Minneapolis, Mobile, Montgomery, Nashville, NewOrleans, NewYork, Newark, Norfolk, OklahomaCity, Olympia, Omaha, Philadelphia, Phoenix, Pittsburgh, PortlandME, PortlandOR, Providence, Raleigh, Reno, Richmond, Roswell, Sacramento, SaltLakeCity, SanAntonio, SanFrancisco, Savannah, Seattle, SiouxFalls, Spokane, Springfield, StLouis, Tampa, Toledo, Tucson, Tulsa, VeroBeach, Washington, Wichita, Wilmington  C1:Anchorage  C2:Fairban
# ...

# %%
points = buildCityPoints('cityTemps.txt', True)hCluster(points, Cluster.singleLinkageDist, 5, True)
# Out:
# Step 0 Merged ['Detroit'] with ['Toledo']Step 1 Merged ['Austin'] with ['SanAntonio']Step 2 Merged ['Baltimore'] with ['Wilmington']Step 3 Merged ['Jackson'] with ['Montgomery']Step 4 Merged ['Philadelphia'] with ['Baltimore', 'Wilmington']Step 5 Merged ['Charleston'] with ['Savannah']Step 6 Merged ['Atlanta'] with ['Birmingham']Step 7 Merged ['Newark'] with ['NewYork']Step 8 Merged ['LittleRock'] with ['Memphis']Step 9 Merged ['Hartford'] with ['Providence']Step 10 Merged ['Albany'] with ['GrandRapids']Step 11 Merged ['Boston'] with ['Bridgeport']Step 12 Merged ['Philadelphia', 'Baltimore', 'Wilmington'] with ['Newark', 'NewYork']Step 13 Merged ['Norfolk'] with ['Raleigh']Step 14 Merged ['Jackson', 'Montgomery'] with ['Charleston', 'Savannah']Step 15 Merged ['Hartford', 'Providence'] with ['Boston', 'Bridgeport']Step 16 Merged ['Cleveland'] with ['Pittsburgh']Step 17 Merged ['Nashville'] with ['Norfolk', 'Raleigh']Step 18 Merged ['AtlantiCity'] with ['Philadelphia', 'Baltimore', 'Wi
# ...
